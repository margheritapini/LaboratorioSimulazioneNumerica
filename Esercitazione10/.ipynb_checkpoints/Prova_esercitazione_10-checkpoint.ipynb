# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica i dati dal file
filename = 'cap_prov_ita.dat'
data = pd.read_csv(filename, sep=' ', header=None, names=['x', 'y'])

# Assegna un numero ai dati da 1 a 110
data['id'] = range(1, 111)

# Ordine specificato
order = [1, 20, 32, 78, 91, 24, 80, 56, 108, 25, 28, 30, 47, 18, 93, 55, 9, 10, 
         76, 86, 8, 36, 12, 60, 23, 43, 21, 26, 71, 45, 38, 46, 84, 82, 95, 110, 
         69, 52, 6, 94, 33, 3, 70, 83, 37, 79, 34, 85, 65, 104, 100, 75, 101, 40, 
         102, 11, 16, 92, 99, 109, 107, 53, 15, 58, 81, 67, 29, 17, 13, 48, 59, 27, 
         103, 105, 61, 106, 14, 4, 96, 7, 31, 42, 89, 39, 2, 68, 57, 50, 72, 44, 
         54, 51, 73, 74, 77, 35, 5, 90, 41, 49, 63, 88, 62, 64, 87, 22, 19, 97, 
         98, 66]

# Estrai i punti nell'ordine specificato
ordered_data = data.set_index('id').loc[order].reset_index()

# Disegna i punti
plt.figure(figsize=(10, 8))
plt.plot(ordered_data['x'], ordered_data['y'], marker='o', linestyle='-', color='b')

# Annotazioni per i punti
for i, row in ordered_data.iterrows():
    plt.annotate(row['id'], (row['x'], row['y']), textcoords="offset points", xytext=(0,10), ha='center')

# Imposta etichette e titolo
plt.xlabel('Ascissa')
plt.ylabel('Ordinata')
plt.title('Punti dal file cap_prov_ita.dat uniti secondo un ordine specificato')

# Mostra il grafico
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica i dati dal file
filename = 'cap_prov_ita.dat'
data = pd.read_csv(filename, sep=' ', header=None, names=['x', 'y'])

# Assegna un numero ai dati da 1 a 110
data['id'] = range(1, 111)

# Ordine specificato
order = [1, 66, 98, 19, 22, 87, 64, 97, 62, 88, 63, 49, 41, 90, 110, 95, 69, 5, 35, 77, 74, 73, 51, 54, 44, 72, 29, 50, 68, 61, 106, 14, 7, 2, 39, 89, 42, 31, 96, 4, 105, 103, 27, 57, 59, 48, 13, 92, 17, 107, 53, 67, 81, 58, 15, 34, 65, 109, 99, 16, 11, 100, 75, 102, 40, 101, 104, 85, 79, 37, 83, 70, 3, 52, 33, 6, 82, 84, 46, 38, 45, 94, 71, 26, 43, 23, 60, 8, 12, 21, 36, 10, 9, 18, 47, 93, 55, 76, 86, 28, 30, 25, 108, 56, 80, 24, 91, 78, 32, 20]

# Estrai i punti nell'ordine specificato
ordered_data = data.set_index('id').loc[order].reset_index()

# Disegna i punti
plt.figure(figsize=(10, 8))
plt.plot(ordered_data['x'], ordered_data['y'], marker='o', linestyle='-', color='b')

# Annotazioni per i punti
for i, row in ordered_data.iterrows():
    plt.annotate(row['id'], (row['x'], row['y']), textcoords="offset points", xytext=(0,10), ha='center')

# Imposta etichette e titolo
plt.xlabel('Ascissa')
plt.ylabel('Ordinata')
plt.title('Punti dal file cap_prov_ita.dat uniti secondo un ordine specificato')

# Mostra il grafico
plt.grid(True)
plt.show()
